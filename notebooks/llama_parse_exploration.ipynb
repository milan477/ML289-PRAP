# %% [markdown]
# # Chetan - LlamaParse PDF Text Extraction

# %%
# SETUP

import os
from pathlib import Path
from llama_parse import LlamaParse
from dotenv import load_dotenv
import sys

# Add src to path
sys.path.append(str(Path.cwd().parent))

from src.config import DATA_DIR

load_dotenv()

print(f"Data directory: {DATA_DIR}")
print(f"API Key loaded: {'Yes' if os.getenv('LLAMA_CLOUD_API_KEY') else 'No'}")
# Out:
# Data directory: /Users/cgoenka/Documents/cs189/ML289-PRAP/data/records
# API Key loaded: Yes

# %%
# Initialize parser

parser = LlamaParse(
    api_key=os.getenv("LLAMA_CLOUD_API_KEY"),
    result_type="markdown",
    verbose=True,
    language="en",
)

# %%
# TESTING ON SINGLE PDF

test_pdf = DATA_DIR / "record10.pdf"

print(f"Parsing: {test_pdf.name}")
documents = parser.load_data(str(test_pdf))

content = "\n\n".join([doc.text for doc in documents])

print(f"\nParsed {len(documents)} page(s)")
print(f"Total content length: {len(content)} characters")
# Out:
# Parsing: record10.pdf
# Started parsing the file under job_id c776e0df-6f6f-4ec4-b8ec-dde1dd753bf6
#
# Parsed 24 page(s)
# Total content length: 66226 characters

# %%
# Display parsed content
print(content)
# Out:
# Sallnas Pollce Department
#
# # Report # 23-100611 - Incident Report Report Cover Sheet
#
# | REPORT DATE / TIME | BEAT / REPORTING DISTRICT | EVENT START DATE / TIME | EVENT END DATE / TIME |
# | ------------------ | ------------------------- | ----------------------- | --------------------- |
# | Oct 20, 2023 20:01 | SN9                       | Oct 20, 2023 16:56      | 16:56                 |
#
# # OFFENSE-1
#
# | OFFENSE CODE                                                                                 | OFFENSE LOCATION                            | OFFENSE START DATE | OFFENSE END DATE   |
# | -------------------------------------------------------------------------------------------- | ------------------------------------------- | ------------------ | ------------------ |
# | VC 2800.2(A) EVADE PEACE OFFICER WITH WANTON DISREGARD FOR SAFETY F - 90Z AIl Other Offenses | ALAMEDA AVE & E ROMIE LN, SALINAS, CA 93901 | Oct 20, 2023 17:00 | Oct 20, 2023 20:10 |
#
# # OFFENSE-2
#
# | OFFENSE CODE                                           | WEAPON / FORCE INVOLVED                    | OFFENSE LOCATION                            | OFFENSE START DATE | OFFENSE END DATE   |
# | ------------------------------------------------------ | ------------------------------------------ | ------------------------------------------- | ------------------ | ------------------ |
# | PC 245(A)(1) ASSAULT W/DEADLY WEAPON:NOT F/ARM F - 520 | Weapon Law Motor Vehicle Vessel Violations | ALAMEDA AVE & E ROMIE LN, SALINAS, CA 93901 | Oct 20, 2023 17:00 | Oct 20, 2023 20:05 |
#
# # OFFENSE-3
#
# | OFFENSE CODE                                                                                        | OFFENSE LOCATION                            | OFFENSE START DATE | OFFENSE END DATE   |
# | --------------------------------------------------------------------------------------------------- | ------------------------------------------- | ------------------ | ------------------ |
# | PC 148(A)(1) OBSTRUCT/RESIST/ETC PUBLIC/PEACE OFFICER/EMERGENCY MED TECH M - 90Z AII Other Offenses | ALAMEDA AVE & E ROMIE LN, SALINAS, CA 93901 | Oct 20, 2023 17:00 | Oct 20, 2023 20:10 |
#
# # OFFENSE-4
#
# | OFFENSE CODE                                                                | OFFENSE LOCATION                            | OFFENSE START DATE | OFFENSE END DATE   |
# | --------------------------------------------------------------------------- | ------------------------------------------- | ------------------ | ------------------ |
# | PC 1203.2(A) PROBATION VIOLATION:REARREST/REVOKE M - 90Z AlI Other Offenses | ALAMEDA AVE & E ROMIE LN, SALINAS, CA 93901 | Oct 20, 2023 17:00 | Oct 20, 2023 20:10 |
#
# # OFFENSE-5
#
# | OFFENSE CODE                                              | OFFENSE LOCATION                            | OFFENSE START DATE | OFFENSE END DATE   |
# | --------------------------------------------------------- | ------------------------------------------- | ------------------ | ------------------ |
# | VC 12500(a) DRIVING MOTOR VEHICLE WITHOUT A VALID LICENSE | ALAMEDA AVE & E ROMIE LN, SALINAS, CA 93901 | Oct 20, 2023 17:00 | Oct 20, 2023 20:13 |
#
# # OFFENSE-6
#
# | OFFENSE CODE                                                                       | OFFENSE LOCATION                            | OFFENSE START DATE | OFFENSE END DATE   |
# | ---------------------------------------------------------------------------------- | ------------------------------------------- | ------------------ | ------------------ |
# | HS 11350(A) POSSESS NARCOTIC CONTROLLED SUBSTANCE F - 35A Drug/Narcotic Violations | ALAMEDA AVE & E ROMIE LN, SALINAS, CA 93901 | Oct 20, 2023 16:56 | Oct 20, 2023 16:56 |
#
# # OFFENSE-7
#
# | OFFENSE CODE                                                              | OFFENSE LOCATION | OFFENSE START DATE | OFFENSE END DATE |
# | ------------------------------------------------------------------------- | ---------------- | ------------------ | ---------------- |
# | HS 11377(A) POSSESS CONTROLLED SUBSTANCE M - 35A Drug/Narcotic Violations |                  |                    |                  |
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Anthony Garcia #30349 Jan 5, 2024 22:24 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Ruben Sanchez #76997 Jan 5, 2024 22:25 (e-signature)
#
# PRINT NAME
#
# Anthony Garcia #30349
#
# PRINT NAME
#
# Ruben Sanchez #76997
#
# Salinas Police Department
#
# Pg 1 of 5
#
# NOTE: Summarized report. More data regarding this report may exist in the RMS.
#
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
#
#
#
#
# Report # 23-100611 - Incident Report Report Cover Sheet Salinas Police Department
#
# # Incident Report
#
# # Offense Location
#
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# # Offense Start Date
#
# Oct 20, 2023 16:56
#
# # Offense End Date
#
# Oct 20, 2023 16:56
#
# # Involved Persons
#
# | Involvement Name       | Home Address     | DOB / Estimated Age | Race     | Sex      |      |
# | ---------------------- | ---------------- | ------------------- | -------- | -------- | ---- |
# | S-1, P-1 Ruben Ayon Jr | No Fixed Address | RANGE               | Hispanic | Male     |      |
# | V-2 Rodolfo Roman      |                  | 1981-04-02          | RANGE    | Hispanic | Male |
# | P-2                    |                  | RANGE               | White    | Male     |      |
#
# # Involved Organizations
#
# | Involvement Name             | Address |
# | ---------------------------- | ------- |
# | V-1, O-1 STATE OF CALIFORNIA |         |
#
# # Involved Property
#
# | Status (NIBRS) | Item Category           | Description                        |
# | -------------- | ----------------------- | ---------------------------------- |
# | Seized         | Drug Narcotic Equipment | 2.53g of suspected Methamphetamine |
# | Seized         | Drug Narcotic Equipment | Blue M30 pills                     |
#
# # Involved Vehicles
#
# | Status (NIBRS) | Item Category                  | Make / Model / Primary Color |
# | -------------- | ------------------------------ | ---------------------------- |
# | None           | Multipurpose Passenger Vehicle | Honda / Odyssey / Silver     |
#
# # Narrative
#
# Portions of this contact were recorded utilizing my patrol vehicles in dash Axon camera.
#
# Due to rapidly evolving events, I was unable to get my body worn camera at the Salinas Police Department for this contact.
#
# On 10/20/2023 at approximately hours I was in duty as a Salinas Police Officer assigned to the K-9 unit with my police K-9 Bolt. I was in full uniform and driving a marked Salinas Police Department patrol vehicle.
#
# At this time, I was contacted by Sergeant R.Sanchez and he told me that California Highway Patrol was in pursuit of a vehicle, and they were requesting the assistance of a K-9. Prior to leaving the police department I was informed that the subject in the pursuit was wanted for assault of deadly weapon on an officer with a vehicle.
#
# As I left the Salinas Police department, I responded code three, and the vehicle was N/B on N,Davis Rd approaching E.Blanco Rd. The direction of travel was updated to E/B on E Blanco Rd towards E. Alisal St. I set up at the intersection of Lorimer St / E.Alisal St and saw that the pursuit was coming in my direction E/B on E/Alisal St. As the pursuit passed me with three California Highway Patrol units in pursuit.
#
# # Reporting Officer Signature / Date
#
# Anthony Garcia #30349 Jan 5, 2024 22:24 (e-signature)
#
# # Supervisor Signature / Date
#
# Ruben Sanchez #76997 Jan 5, 2024 22:25 (e-signature)
#
# # Print Name
#
# Anthony Garcia #30349
#
# Ruben Sanchez #76997
#
# Salinas Police Department Pg 2 of 5
#
#
#
# Report # 23-100611 - Incident Report Report Cover Sheet Salinas Police Department
#
# I asked Monterey County communications if the California Highway Patrol wanted Salinas P.D. to take over the pursuit. California Highway Patrol said that they wanted Salinas P.D. to take over the pursuit.
#
# I advised County communications that I was going to be taking over the pursuit at the intersection of E. Alisal St / Church St where I assumed the number one position in the pursuit and Sergeant Roman was in the number two position. The driver of the vehicle later identified as Ruben Ayon led Salinas Police Officers on a 1.38-mile pursuit through south Salinas.
#
# Please refer to Sergeant Roman's report for further details of the pursuit and his observations.
#
# I am currently trained and certified in the Pursuit intervention technique with the Salinas Police Department. I attempted to PIT Ayon numerous times however every time I attempted the PIT Ayon either slammed on his breaks or drove from side to side within the curb lines avoiding the PIT.
#
# When we reached the area of Alameda Dr and E Romie Lane Sergeant Roman passed me on the right-hand side and attempted the Pursuit intervention technique and temporarily immobilized Ayon's vehicle. After the PIT maneuver Ayon's vehicle ended up facing in a W/B direction on the west curb line on Alameda Ave in the driveway of 339 E. Romie Ln. Ayon then put the vehicle into drive and tried to go around my patrol car, but I pulled forward and forced his vehicle to go back into the driveway as he attempted to go through the sidewalk but was blocked partially by my patrol car and a fixed light pole. At this time Sergeant Roman pulled his vehicle directly behind Avon and Ayon backed into him. Ayon pulled forward and created space between Sergeant Roman's patrol car. Sergeant Roman and I exited our patrol cars and challenged Ayon at gun point. Ayon then accelerated in reverse as Sergeant Roman was getting back into his vehicle and rammed Sergeant Roman. Sergeant Roman was able to push Ayon's vehicle with his patrol car onto a tree causing the front tires to be off the ground.
#
# I exited my patrol car and once again challenged Ayon to put his hands up. Ayon refused to put his hands up and started to press on the accelerator and manipulate the gear shifter. I could see the front tires spinning as Ayon was pressing on the accelerator and was also moving the steering wheel left and right as if he was trying to disengage the vehicle from the tree. Ayon continually reached under the seat to the vehicle on both sides. The vehicle was resting on top of a tree at an angle which also made it difficult to see Ayon's hands. Officers kept challenging Ayon to put his hands up however he refused and kept reaching under the seat.
#
# Officer J. Munoz arrived on scene and had broken right front passenger window out with a 40mm round. Ayon still refused to put his hands up and Officer Munoz broke right rear passenger window as well in attempts to find a way into the vehicle to deploy K-9 Bolt. Detective Scaggs, who was also on scene, gave Ayon a K9 announcement however he refused to comply with commands.
#
# K-9 Bolt was used for the following reasons:
#
# The suspect was actively resisting arrest and evading officers. Based on the fact that Ayon had demonstrated his willingness to endanger the lives of the public and the responding officers showing no regard for the safety of others and that Ayon was an unsearched felony suspect who had committed a serious offense, I deployed K-9 Bolt into the vehicle to apprehend Ayon.
#
# | REPORTING OFFICER SIGNATURE / DATE                    | SUPERVISOR SIGNATURE / DATE                          |
# | ----------------------------------------------------- | ---------------------------------------------------- |
# | Anthony Garcia #30349 Jan 5, 2024 22:24 (e-signature) | Ruben Sanchez #76997 Jan 5, 2024 22:25 (e-signature) |
# | PRINT NAME                                            | PRINT NAME                                           |
# | Anthony Garcia #30349                                 | Ruben Sanchez #76997                                 |
#
# Salinas Police Department
#
# NOTE: Summarized report. More data regarding this report may exist in the RMS.
#
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35.
#
# Pg 3 of 5
#
#
#
# Report # 23-100611 - Incident Report Report Cover Sheet Salinas Police Department
#
# # Incident Report
#
# It was my fear that if Ayon was to get back on the road, he would pose an immediate danger to officers and the public safety once again.
#
# The use of the K-9 also greatly decreased the threat to officers and the public during the apprehension of suspect Ayon.
#
# The use of the K-9 Bolt was the less than lethal force option. After K-9 Bolt was in the vehicle he apprehended Ayon by biting him on the right upper arm. I approached the vehicle from the passenger side and due to the fact that the vehicle was inclined I could not enter the vehicle from the passenger side. I ran around the vehicle and made my way to the driver's side door. I had to push the back sliding door open to get into the vehicle. I instructed the Officers that were assisting me to pull Ayon out of the vehicle. Once Ayon was taken out of the vehicle I gave K-9 Bolt the release command and he released from the bite.
#
# I then secured K-9 Bolt in the rear of my patrol car and went back to assist with Ayon.
#
# Medical personnel were already on scene and when the scene was secure, they tended to Ayon's injuries. Ayon was transported to Natividad Hospital for a jail clearance and his injuries.
#
# When I contacted Ayon at the hospital, I advised him of his Miranda rights and the following is a summary of his statement: I asked Ayon why he didn't stop for that patrol cars that were pursing him because he was afraid of the police because they had originally tried to take him out of the car in Marina. Ayon said that the Marina cops have been dicks to him in the past and today they pointed a gun at him to get him out of the car therefore he fled from them. Ayon said that when he was on highway 68 the officers had stopped chasing him and he pulled into the Toro Park residential area. Ayon said when he drove out of the Toro Park residential area CHP had started to pursue him again.
#
# I asked Ayon if he saw the line of patrol cars behind him and he said that he didn't because the mirror was not in the right position. I told Ayon that I had tried to PIT his vehicle several times however he kept braking and then accelerating. I asked Ayon where he was driving to, and Ayon responded and said that he didn't have a plan and was going to continue driving until officers stopped chasing him. I asked after his vehicle was PIT why did he continue to attempt to escape. Ayon said that he didn't know what he was thinking, and he was sorry that he made a stupid mistake. I asked Ayon why he kept reaching under the seats when officers were challenging him to put his hands up. Ayon said that he was trying to gather all of his money and put it all in his wallet because it was his life savings. I told Ayon that I even gestured to him with my hands up and see if would put his hands up and he refused. Ayon asked me what his charges and I were gave them to him and he said that he was sorry and he made a mistake.
#
# I confronted Ayon about a large number of blue pills with an imprint of M30 on it. I asked Ayon if they were M30 pills and he said that they were. Ayon said that everything illegal in the vehicle belonged to him.
#
# Please refer to Officer I. Urquizo's supplement report for further details of his findings of the contraband.
#
# | REPORTING OFFICER SIGNATURE / DATE                    | SUPERVISOR SIGNATURE / DATE                          |
# | ----------------------------------------------------- | ---------------------------------------------------- |
# | Anthony Garcia #30349 Jan 5, 2024 22:24 (e-signature) | Ruben Sanchez #76997 Jan 5, 2024 22:25 (e-signature) |
# | PRINT NAME                                            | PRINT NAME                                           |
# | Anthony Garcia #30349                                 | Ruben Sanchez #76997                                 |
#
# Salinas Police Department
#
# NOTE: Summarized report. More data regarding this report may exist in the RMS.
#
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35.
#
# Pg 4 of 5
#
#
#
#
# Report # 23-100611 - Incident Report
#
# # Report Cover Sheet
#
# # Salinas Police Department
#
# Pg 5 of 5
#
# Crime scene investigator G. Garcia was on scene and took photos of Ayon's injuries.
#
# Dr. Adam Kincaid was the treating doctor and cleared Ayon to be transported to Monterey County Jail. Ayon had several lacerations to upper right arm that required 35 staples and 2 sutures.
#
# Records check of Ayon revealed that he did not have any wants or warrants however he was on probation court case # 20CR009872.
#
# Ayon was transported to the Monterey County Jail and booked on the listed charges.
#
# I request this report be forwarded to the Monterey County District Attorney's office for their review and prosecution of Ayon for the listed charges.
#
# | REPORTING OFFICER SIGNATURE / DATE                    | SUPERVISOR SIGNATURE / DATE                          |
# | ----------------------------------------------------- | ---------------------------------------------------- |
# | Anthony Garcia #30349 Jan 5, 2024 22:24 (e-signature) | Ruben Sanchez #76997 Jan 5, 2024 22:25 (e-signature) |
# | PRINT NAME                                            | PRINT NAME                                           |
# | Anthony Garcia #30349                                 | Ruben Sanchez #76997                                 |
#
# Salinas Police Department
#
# Pg 5 of 5
#
# NOTE: Summarized report. More data regarding this report may exist in the RMS.
#
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35.
#
#
#
#
#
# Report # 23-100611 - Supplement - 1 Report Salinas Police Department
#
# # Report # 23-100611 - Supplement - 1 Report
#
# | REPORT DATE / TIME | EVENT START DATE / TIME | EVENT END DATE / TIME | PREPARED BY            |
# | ------------------ | ----------------------- | --------------------- | ---------------------- |
# | Oct 20, 2023 16:43 | Oct 20, 2023 14:27      | 16:26                 | Stephanie Moore #58125 |
#
# # REPORT DESCRIPTION
#
# Photographs
#
# # SUPPLEMENT TYPE
#
# Add Property/Evidence
#
# # NARRATIVE
#
# # EVIDENCE
#
# The suspect's black sweater and cartoon ballcap were booked into Salinas Evidence. Photographs of the scene at Alameda Ave and E Romie Ln were also submitted to Salinas Evidence.
#
# # NARRATIVE
#
# On 10/20/23 at approximately 1427 hours, CHP requested assistance from Salinas PD for a pursuit heading into Salinas city limits. The pursuit ended in the driveway of 339 E Romie Ln on the Alameda Ave side. I arrived at approximately 1446 hours.
#
# This area of Alameda Ave and E Romie Lane is a combined residential and business area. Alameda Ave is a paved road that runs north and south. Both the east and west sides of Alameda Ave are residential homes. E Romie Ln is a paved road that runs east and west. The north and south sides of E Romie Ln are combined residential homes and medical businesses.
#
# I took pristine overall photographs of the scene, including the vehicles involved. Tire friction marks started at the intersection of Alameda Ave and Hawthorne St. The friction marks traveled in a southern direction along Alameda Ave and stopped at the driveway of E Romie Ln.
#
# I also photographed the suspect's cellphone, multicolored ballcap, a black sweater with blood, and the interior of the Honda Odyssey.
#
# Once photographs were taken, CSO Quintero and I collected the following items of evidence: a red cell phone, a black sweater with blood, and a multicolored ball cap. The cell phone was given to Officer Calender.
#
# At approximately 1626 hours, I transported the bloody sweater and ballcap to the Salinas PD. I arrived at approximately 1632 hours.
#
# The black sweater with blood was booked into Salinas Evidence in blood locker number one. The multicolor ballcap was booked into the Salinas Evidence intake lockers.
#
# # DISPOSITION
#
# Attach this supplement to the master report.
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# | Stephanie Moore #58125 | Oct 21, 2023 15:46 (e-signature) |
# | ---------------------- | -------------------------------- |
#
# # SUPERVISOR SIGNATURE / DATE
#
# | Danny Warner #92283 | Oct 23, 2023 18:16 (e-signature) |
# | ------------------- | -------------------------------- |
#
# # PRINT NAME
#
# | Stephanie Moore #58125 | Danny Warner #92283 |
# | ---------------------- | ------------------- |
#
# Salinas Police Department Pg 1 of 3 Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35.
#
#
#
# Report # 23-100611 - Supplement - 1 Report Salinas Police Department
#
# Nothing further.
#
# End of report.
#
# # INVOLVED PERSONS
#
# | INVOLVED PERSON-1 NAME (LAST, FIRST MIDDLE) | DOB / ESTIMATED AGE RANGE |
# | ------------------------------------------- | ------------------------- |
# | P-1 Ayon, Ruben Jr                          | 1981-04-02                |
# | SEX                                         | RACE / ETHNICITY          |
# | Male                                        | Hispanic                  |
# | HOME ADDRESS                                | No Fixed Address          |
# | INVOLVEMENT TYPE                            | Suspect                   |
#
# # INVOLVED LOCATIONS
#
# LOCATION
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# # VEHICLE / PROPERTY &#x26; ITEMS SUMMARY
#
# | DESCRIPTION / MAKE / MODEL / COLOR | STATUS / DATE / REASON FOR CUSTODY | VIN # / SERIAL # | QTY. | TOTAL ($) |
# | ---------------------------------- | ---------------------------------- | ---------------- | ---- | --------- |
# | Black sweater w/blood from suspect | None / Oct 20, 2023 / Evidence     | UNKNOWN          |      | UNKNOWN   |
# | Cartoon ballcap from suspect       | None / Oct 20, 2023 / Evidence     | UNKNOWN          |      | UNKNOWN   |
#
# # PROPERTY &#x26; ITEMS ADDENDUM
#
# | 23-100611-5 OTHER ITEM - BLACK SWEATER W/BLOOD FROM SUSPECT |                                    |
# | ----------------------------------------------------------- | ---------------------------------- |
# | ITEM CATEGORY                                               | Clothes Furs                       |
# | DESCRIPTION                                                 | Black sweater w/blood from suspect |
# | IN POSSESSION OF                                            | Ruben Ayon Jr                      |
# | STATUS (NIBRS)                                              | None                               |
# | STATUS DATE                                                 | Oct 20, 2023                       |
# | TOTAL ($)                                                   | UNKNOWN                            |
# | IN POLICE CUSTODY/                                          | Yes                                |
# | REASON FOR POLICE CUSTODY                                   | Evidence                           |
# | RECOVERING OFFICER / ID # / PERSON                          | Stephanie Moore #58125             |
# | STORAGE LOCATION / PERSON / DESTINATION / INTAKE PERSON     | MAIN FACILITY > BLOOD LOCKERS      |
#
# # 23-100611-6 OTHER ITEM - CARTOON BALLCAP FROM SUSPECT
#
# | ITEM CATEGORY | Clothes Furs                 |
# | ------------- | ---------------------------- |
# | DESCRIPTION   | Cartoon ballcap from suspect |
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# | Stephanie Moore #58125 | Oct 21, 2023 15:46 (e-signature) |
# | ---------------------- | -------------------------------- |
#
# # SUPERVISOR SIGNATURE / DATE
#
# | Danny Warner #92283 | Oct 23, 2023 18:16 (e-signature) |
# | ------------------- | -------------------------------- |
#
# # PRINT NAME
#
# | Stephanie Moore #58125 | Danny Warner #92283 |
# | ---------------------- | ------------------- |
#
# Salinas Police Department Pg 2 of 3 Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35.
#
#
#
# Report # 23-100611 - Supplement - 1 Report Salinas Police Department
#
# # SUSPECT
#
# Ruben Ayon Jr
#
# | STATUS (NIBRS) | STATUS DATE  | TOTAL ($) | IN POLICE CUSTODY / TOWED BY PD |
# | -------------- | ------------ | --------- | ------------------------------- |
# | None           | Oct 20, 2023 | VALUE     | UNKNOWN Yes                     |
#
# # REASON FOR POLICE CUSTODY
#
# Evidence
#
# # RECOVERING OFFICER / ID # / PERSON
#
# Stephanie Moore #58125
#
# # STORAGE LOCATION / PERSON / DESTINATION / INTAKE PERSON
#
# MAIN FACILITY > EVIDENCE INTAKE
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Stephanie Moore #58125 Oct 21, 2023 15:46 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 18:16 (e-signature)
#
# # PRINT NAME
#
# Stephanie Moore #58125
#
# # PRINT NAME
#
# Danny Warner #92283
#
# Salinas Police Department
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35.
#
# Pg 3 of 3
#
#
#
#
# Report # 23-100611 - Supplement - 2 Report Salinas Police Department
#
# # Report # 23-100611 - Supplement - 2 Report
#
# | REPORT DATE / TIME | EVENT START DATE / TIME - EVENT END DATE / TIME | PREPARED BY       |
# | ------------------ | ----------------------------------------------- | ----------------- |
# | Oct 20, 2023 16:44 | Oct 20, 2023 16:56 - 16:56                      | Ivan Urquizo #231 |
#
# # REPORT DESCRIPTION
#
# EVIDENCE
#
# # SUPPLEMENT TYPE
#
# Add Property/Evidence
#
# # NARRATIVE
#
# I was wearing an Axon body-worn camera, which was activated during portions of this incident. These videos were uploaded to Evidence.com. This report is a synopsis of the incident. For further details, refer to my BWC footage. The blue M30 pills, the suspected methamphetamine, the small clear plastic spoon, the five clear baggies, and the gray pouch were all booked into an evidence locker at the Salinas Police Department. I took pictures of the items and later uploaded them to Evidence.com.
#
# On 10/20/23 at approximately 1343 hours, County Communications received a call from California Highway Patrol. They were assisting Marina PD in pursuing a vehicle that was now driving toward Salinas.
#
# The vehicle entered Salinas, and a pursuit was initiated. The vehicle was ultimately brought to a stop. I was not involved in the pursuit. For further details, refer to K9 Officer A. Garcia's incident report.
#
# Upon arrival, I assisted in taking the suspect, Ruben Ayon Jr., into custody.
#
# Later, Officer K. Han and I searched the vehicle prior to it getting towed away. While conducting the search, I located a small gray pouch with a black zipper. It was on the floorboard, between the driver's door and seat. Inside the pouch was a bundle of many blue M30 pills. Based on my training and experience, I believed the M30 pills to be Oxycodone pills, frequently laced with fentanyl.
#
# The pouch also contained another small bundle with a white substance inside. I could not initially tell what the substance appeared to be through the baggie, but I believed it to be cocaine or methamphetamine. There was also a small, clear plastic spoon in the exterior pocket of the pouch. I did not open the bundles on the scene due to the risk of them being laced with fentanyl.
#
# Community Service Officer S. Moore took pictures of the pouch and bundles. Refer to her supplement report for further details.
#
# I later drove to the Salinas Police Department to book the bundles for evidence.
#
# I removed the blue M30 pills and counted them in rows of 10. There were 118 total blue M30 pills. I opened the other bundle with the white substance. Once I opened the bundle, it was clear it was a
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Ivan Urquizo #231 Oct 22, 2023 16:48 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 18:16 (e-signature)
#
# PRINT NAME
#
# Ivan Urquizo #231
#
# PRINT NAME
#
# Danny Warner #92283
#
# Salinas Police Department Pg 1 of 5
#
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
#
#
#
# Report # 23-100611 - Supplement - 2 Report Salinas Police Department
#
# white and shard-like substance. My training and experience show that this substance is usually methamphetamine. I weighed the white shard-like substance with the baggie. It weighed approximately 2.53 grams.
#
# I tested the white shard-like substance at the Salinas Police Department. I have received training in presumptive testing procedures. Per product instructions and guidelines, I conducted a presumptive test of the substance with positive results for methamphetamine.
#
# There were also five unused baggies in the outside pocket of the gray pouch. The blue M30 pills, the suspected methamphetamine, the small clear plastic spoon, the five clear baggies, and the gray pouch were all booked into an evidence locker at the Salinas Police Department. I took pictures of the items and later uploaded them to Evidence.com.
#
# This concludes my involvement in this case
#
# # INVOLVED PERSONS
#
# | INVOLVED PERSON-1 NAME (LAST, FIRST MIDDLE) | DOB / ESTIMATED AGE RANGE |
# | ------------------------------------------- | ------------------------- |
# | P-1 Ayon, Ruben Jr                          | 1981-04-02                |
# | SEX                                         | RACE / ETHNICITY          |
# | Male                                        | Hispanic                  |
# | HOME ADDRESS                                | No Fixed Address          |
# | INVOLVEMENT TYPE                            | Suspect                   |
#
# # INVOLVED ORGANIZATIONS
#
# | INVOLVED ORGANIZATION-1 NAME | INVOLVEMENT TYPE |
# | ---------------------------- | ---------------- |
# | O-1 STATE OF CALIFORNIA      | Victim           |
#
# # INVOLVED LOCATIONS
#
# LOCATION
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# # VEHICLE / PROPERTY &#x26; ITEMS SUMMARY
#
# | DESCRIPTION / MAKE / MODEL / COLOR                  | STATUS / DATE / REASON FOR CUSTODY | VIN # / SERIAL # | QTY. | TOTAL ($) |
# | --------------------------------------------------- | ---------------------------------- | ---------------- | ---- | --------- |
# | Blue M30 pills / M30 / Blue                         | Seized / Oct 20, 2023 / Evidence   |                  | 118  | UNKNOWN   |
# | 2.53g of suspected Methamphetamine / White          | Seized / Oct 20, 2023 / Evidence   |                  |      | UNKNOWN   |
# | small gray zipper pouch / Smokezilla / Gray & Black | Seized / Oct 20, 2023 / Evidence   |                  | 1    | UNKNOWN   |
# | Small clear plastic spoon / Clear                   | Seized / Oct 20, 2023 / Evidence   |                  | 1    | UNKNOWN   |
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Ivan Urquizo #231 Oct 22, 2023 16:48 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 18:16 (e-signature)
#
# # PRINT NAME
#
# Ivan Urquizo #231
#
# # PRINT NAME
#
# Danny Warner #92283
#
# Salinas Police Department
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
#
#
# Report # 23-100611 - Supplement - 2 Report Salinas Police Department
#
# # PROPERTY &#x26; ITEMS ADDENDUM
#
# # 23-100611-1 OTHER ITEM - BLUE M30 PILLS
#
# | ITEM CATEGORY                                |                                                         | BIOHAZARD                      |          |
# | -------------------------------------------- | ------------------------------------------------------- | ------------------------------ | -------- |
# | Drug Narcotic Equipment                      |                                                         | YES                            |          |
# | EXPLAIN BIOHAZARD                            | suspected fentanyl                                      |                                |          |
# | DESCRIPTION                                  | Blue M30 pills                                          |                                |          |
# | COLOR                                        | Blue                                                    |                                |          |
# | IN POSSESSION OF                             | Ruben Ayon Jr                                           |                                |          |
# | STATUS (NIBRS)                               | STATUS DATE                                             | TOTAL ($)                      | QUANTITY |
# | Seized                                       | Oct 20, 2023                                            | VALUE                          | 118      |
# |                                              |                                                         | UNKNOWN                        |          |
# | IN POLICE CUSTODY/ REASON FOR POLICE CUSTODY | TOWED BY PD                                             | Evidence                       | Yes      |
# | RECOVERING OFFICER / ID # / PERSON           | Ivan Urquizo #231                                       |                                |          |
# |                                              | STORAGE LOCATION / PERSON / DESTINATION / INTAKE PERSON | MAIN FACILITY > INTAKE LOCKERS |          |
# | RECOVERED LOCATION                           | ALAMEDA AVE & E ROMIE LN, SALINAS, CA 93901             |                                |          |
#
# # 23-100611-2 OTHER ITEM - 2.53G OF SUSPECTED METHAMPHETAMINE
#
# | ITEM CATEGORY                     | BIOHAZARD                          |           |                     |
# | --------------------------------- | ---------------------------------- | --------- | ------------------- |
# | Drug Narcotic Equipment           | YES                                |           |                     |
# | EXPLAIN BIOHAZARD                 | could possibly have fentanyl       |           |                     |
# | DESCRIPTION                       | 2.53g of suspected Methamphetamine |           |                     |
# | COLOR                             | White                              |           |                     |
# | IN POSSESSION OF                  | Ruben Ayon Jr                      |           |                     |
# | STATUS (NIBRS)                    | STATUS DATE                        | TOTAL ($) | IN POLICE CUSTODY / |
# | Seized                            | Oct 20, 2023                       | VALUE     | TOWED BY PD         |
# |                                   |                                    | UNKNOWN   | Yes                 |
# | REASON FOR POLICE CUSTODY         | Evidence                           |           |                     |
# | RECOVERING OFFICER /ID # / PERSON | Ivan Urquizo #231                  |           |                     |
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Ivan Urquizo #231 Oct 22, 2023 16:48 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 18:16 (e-signature)
#
# # PRINT NAME
#
# Ivan Urquizo #231
#
# # PRINT NAME
#
# Danny Warner #92283
#
# Salinas Police Department Pg 3 of 5 Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
#
#
# Report # 23-100611 - Supplement - 2 Report Salinas Police Department
#
# # STORAGE LOCATION / PERSON / DESTINATION / INTAKE PERSON
#
# MAIN FACILITY > INTAKE LOCKERS
#
# # RECOVERED LOCATION
#
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# | 23-100611-3                       | OTHER ITEM - SMALL GRAY ZIPPER POUCH | BIOHAZARD |          |   |
# | --------------------------------- | ------------------------------------ | --------- | -------- | - |
# | ITEM CATEGORY                     | YES                                  | NO        |          |   |
# | Other                             |                                      |           |          |   |
# | EXPLAIN BIOHAZARD                 | could have fentanyl                  |           |          |   |
# | DESCRIPTION                       | small gray zipper pouch              |           |          |   |
# | COLOR                             | Gray/ Black                          |           |          |   |
# | IN POSSESSION OF                  | Ruben Ayon Jr                        |           |          |   |
# | STATUS (NIBRS)                    | STATUS DATE                          | TOTAL ($) | QUANTITY |   |
# | Seized                            | Oct 20, 2023                         | VALUE     | 1        |   |
# |                                   |                                      | UNKNOWN   |          |   |
# | IN POLICE CUSTODY/                | REASON FOR POLICE CUSTODY            |           |          |   |
# | TOWED BY PD                       | Evidence                             |           |          |   |
# | Yes                               |                                      |           |          |   |
# | RECOVERING OFFICER /ID # / PERSON | Ivan Urquizo #231                    |           |          |   |
#
# # STORAGE LOCATION / PERSON / DESTINATION / INTAKE PERSON
#
# MAIN FACILITY > INTAKE LOCKERS
#
# # RECOVERED LOCATION
#
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# | 23-100611-4                        | OTHER ITEM - SMALL CLEAR PLASTIC SPOON | BIOHAZARD |          |
# | ---------------------------------- | -------------------------------------- | --------- | -------- |
# | ITEM CATEGORY                      |                                        | YES       | NO       |
# | Other                              |                                        |           |          |
# | EXPLAIN BIOHAZARD                  | could contain fentanyl                 |           |          |
# | DESCRIPTION                        | Small clear plastic spoon              |           |          |
# | COLOR                              | Clear                                  |           |          |
# | IN POSSESSION OF                   | Ruben Ayon Jr                          |           |          |
# | STATUS (NIBRS)                     | STATUS DATE                            | TOTAL ($) | QUANTITY |
# | Seized                             | Oct 20, 2023                           | VALUE     | 1        |
# |                                    |                                        | UNKNOWN   |          |
# | IN POLICE CUSTODY                  | REASON FOR POLICE CUSTODY              |           |          |
# | TOWED BY PD                        | Evidence                               |           |          |
# | Yes                                |                                        |           |          |
# | RECOVERING OFFICER / ID # / PERSON | Ivan Urquizo #231                      |           |          |
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Ivan Urquizo #231 Oct 22, 2023 16:48 (e-signature)
#
# # PRINT NAME
#
# Ivan Urquizo #231
#
# Salinas Police Department
#
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 18:16 (e-signature)
#
# # PRINT NAME
#
# Danny Warner #92283
#
# Pg 4 of 5
#
#
#
# Report # 23-100611 - Supplement - 2 Report Salinas Police Department
# # STORAGE LOCATION / PERSON / DESTINATION / INTAKE PERSON
#
# # MAIN FACILITY > INTAKE LOCKERS
#
# # RECOVERED LOCATION
#
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# | 23-100611-7                       | OTHER ITEM - 5 SMALL PLASTIC BAGGIES | BIOHAZARD |
# | --------------------------------- | ------------------------------------ | --------- |
# | ITEM CATEGORY                     | YES                                  | NO        |
# | Other                             |                                      |           |
# | EXPLAIN BIOHAZARD                 | could contain fentanyl               |           |
# | DESCRIPTION                       | 5 small plastic baggies              |           |
# | COLOR                             | Clear                                |           |
# | IN POSSESSION OF                  | Ruben Ayon Jr                        |           |
# | STATUS (NIBRS)                    | STATUS DATE                          | TOTAL ($) |
# | Seized                            | Oct 20, 2023                         | VALUE     |
# | 5                                 | UNKNOWN                              |           |
# | IN POLICE CUSTODY/                | REASON FOR POLICE CUSTODY            |           |
# | TOWED BY PD                       | Evidence                             | Yes       |
# | RECOVERING OFFICER /ID # / PERSON | Ivan Urquizo #231                    |           |
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Ivan Urquizo #231 Oct 22, 2023 16:48 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 18:16 (e-signature)
#
# # PRINT NAME
#
# Ivan Urquizo #231
#
# Danny Warner #92283
#
# Salinas Police Department
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
#
#
# Report # 23-100611 - Supplement - 3 Report Salinas Police Department
#
# # Report # 23-100611 - Supplement - 3 Report
#
# | REPORT DATE / TIME | EVENT START DATE / TIME - EVENT END DATE / TIME | PREPARED BY          |
# | ------------------ | ----------------------------------------------- | -------------------- |
# | Oct 21, 2023 08:11 | Oct 20, 2023 16:56 - 16:56                      | Jeffrey Munoz #58964 |
#
# # REPORT DESCRIPTION
#
# Supplement
#
# # SUPPLEMENT TYPE
#
# General - arrest assist
#
# # NARRATIVE
#
# # Evidence:
#
# Upon contact with Ayon, I activated my Body Worn Camera and downloaded it to Evidence.com.
#
# # Narrative:
#
# On the above date and time, I responded to the area of Alameda and Romie Lane to assist in the arrest of Ruben Ayon Jr. For further details of the pursuit, see the master report.
#
# Before my arrival, the Officer informed County Communications that Ayon had rammed his vehicle into the Officer's vehicle.
#
# The following is a summary of my involvement. See my BWC for further details.
#
# Upon arrival, I observed that Ayon's Honda Odyssey was pushed onto a small tree, and a fully marked police vehicle was behind it. I pulled out my gun and observed Ayon reaching under his seat and looking for what I thought was a gun. Surrounding Officers had their guns out, pointed at Ayon, and ordered him repeatedly to put his hands up. Ayon continued to look and reach around the cab of his vehicle and did not comply with orders to put his hands up.
#
# I de-escalated and holstered my gun and pulled out my department-issued 40mm foam munition. I fired two rounds at the front passenger window, and the projectiles bounced off the window. The third round shattered the front window. I shot the fourth and final round at the passenger rear window, which shattered. Ayon still did not comply and was attempting to move his vehicle. He had it in gear, and the front wheels were spinning as he tried to drive his vehicle.
#
# This concluded my part in this investigation, and for further details, see my BWC.
#
# # INVOLVED PERSONS
#
# | INVOLVED PERSON-1 NAME (LAST, FIRST MIDDLE) | DOB / ESTIMATED AGE RANGE |
# | ------------------------------------------- | ------------------------- |
# | P-1 Ayon, Ruben Jr                          | 1981-04-02                |
# | SEX                                         | RACE / ETHNICITY          |
# | Male                                        | Hispanic                  |
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Jeffrey Munoz #58964 Oct 21, 2023 08:30 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 20:15 (e-signature)
#
# # PRINT NAME
#
# Jeffrey Munoz #58964
#
# # PRINT NAME
#
# Danny Warner #92283
#
# Salinas Police Department
# Pg 1 of 2
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
#
#
#
# Report # 23-100611 - Supplement - 3 Report Salinas Police Department
#
# # HOME ADDRESS
#
# No Fixed Address
#
# # INVOLVEMENT TYPE
#
# Arrested
#
# # INVOLVED LOCATIONS
#
# # LOCATION
#
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Jeffrey Munoz #58964 Oct 21, 2023 08:30 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 20:15 (e-signature)
#
# # PRINT NAME
#
# Jeffrey Munoz #58964
#
# # PRINT NAME
#
# Danny Warner #92283
#
# Salinas Police Department
#
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
# Pg 2 of 2
#
#
#
#
# Report # 23-100611 - Supplement - 4 Report Salinas Police Department
#
# # Report # 23-100611 - Supplement - 4 Report
#
# | REPORT DATE / TIME | EVENT START DATE / TIME - EVENT END DATE / TIME | PREPARED BY          |
# | ------------------ | ----------------------------------------------- | -------------------- |
# | Oct 21, 2023 10:56 | Oct 20, 2023 16:33 - 16:56                      | Rodolfo Roman #75561 |
#
# # REPORT DESCRIPTION
#
# Supplement Pursuit and P.I.T. maneuver
#
# # SUPPLEMENT TYPE
#
# General - arrest assist
#
# # NARRATIVE
#
# On 10-20-23, I was assigned as the sergeant supervising our Day Watch Shift. At approximately 1426 hours, Monterey County Dispatch advised me of C.H.P.'s involvement in a pursuit and requested a K-9 officer. The want on the suspect was assault with a deadly weapon on a police officer. K-9 Officer Anthony Garcia was about to start since Second Watch was at the station. I and K-9 Officer Garcia responded from the police station Code 3 towards the pursuit.
#
# At approximately 1433 hours, we caught up to the pursuit at E. Alisal St and Homestead Ave. The suspect vehicle, a silver Honda Odyssey, CA plate # , was traveling eastbound on E. Alisal St. with three CHP units pursuing the vehicle. The suspect vehicle ran a red light at the intersection. I and Officer Garcia began to trail the pursuit, At E. Alisal St. and Riker Ave. CHP requested us to take over the pursuit. Officer Garcia is PIT-trained and informed me he would attempt a P.I.T. maneuver on the vehicle. I acknowledge Officer Garcia's traffic. The following is the direction of travel and the violations during the 1.38-mile pursuit.
#
# # Eastbound on W. Alisal St.
#
# - W. Alisal St and Church St. - Red light violation (21453 VC)
# - W. Alisal St. and Lincoln Ave. - Red light violation (21453 VC)
# - W. Alisal St. and Salinas St - Red light violation (21453 VC)
#
# # Southbound on Salinas St.
#
# - John St. and S. Main St. - Red light violation (21453 VC)/Improper Lane right turn (22100 VC). Used left turn lane.
#
# # Southbound on S. Main St.
#
# - Westbound on Winham St. - driving on the wrong side of the roadway (21651(b) VC)
# - (Entering residential area - 25 mph zone) - Avg. Speeds of 35-40 miles for suspect.
# - Winham St and Pajaro St. - Stop sign violation (22450 VC)
# - Southbound on Pajaro St. - driving on the wrong side of the roadway (21651(b) VC)
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Rodolfo Roman #75561 Oct 21, 2023 11:09 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 20:43 (e-signature)
#
# # PRINT NAME
#
# Rodolfo Roman #75561
#
# Danny Warner #92283
#
# Salinas Police Department
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
# Pg 1 of 5
#
#
#
# Report # 23-100611 - Supplement - 4 Report Salinas Police Department
#
# Pajaro St. and Maple St. - Stop sign violation (22450 VC)
#
# Maple St. and California St. - Stop sign violation (22450 VC)
#
# Eastbound on Maple St. - driving on the wrong side of the roadway (21651(b) VC)
#
# Eastbound on Santa Lucia Ave. - driving on the wrong side of the road (21651(b) VC)
#
# Southbound on Alameda Ave.
#
# Santa Lucia Ave. and Alameda Ave. - Stop sign violation (22450 VC)
#
# Alameda Ave. and Maplewood Dr. - Stop sign violation (22450 VC)
#
# Alameda Ave and Hawthorne St. - P.I.T. Maneuver on Suspect Vehicle.
#
# During the pursuit, I observed Officer Garcia attempting to place himself in a position to conduct a P.I.T. maneuver. The suspect kept zig-zagging and would drive on the opposite side of the roadway to prevent Officer Garcia from conducting the P.I.T. maneuver. I observed in the area of Pajaro St., at least once, the suspect vehicle went into the opposite lane, and a vehicle was coming from the opposite direction. That vehicle pulled to the curb to get out of the way.
#
# As we were traveling southbound on Alameda Ave. I knew if we continued straight, we were going to go into a school zone. I am currently trained and certified in the Pursuit intervention technique with the Salinas Police Department. At Alameda Ave. and Hawthorne St. Officer Garcia attempted to P.I.T. the vehicle, and the suspect slammed his brakes, reducing his speed considerably. Officer Garcia had also slowed down as well. The suspect took off again, and since I hadn't slowed down yet, I accelerated, which helped me catch up to the suspect vehicle and placed my S.U.V. in a position to conduct the P.I.T. maneuver. I placed my front push bumper on the right rear wheel well area, and I successfully P.I.T. the suspect vehicle into the driveway of 339 E. Romie Lane.
#
# ...
#
# As officers arrived, Officer Garcia coordinated with officers and Officer Munoz to break the passenger side windows. Officer Munoz shot two 40mm less lethal rounds to the front passenger side window, and both rounds bounced upward. The third 40mm less lethal round broke the front window. A fourth 40mm less lethal round broke the rear passenger window. As officers arrived, I informed them that the 40mm launcher was being used due to the sound sounding like gunfire and not wanting officers to confuse it with gunfire.
#
# After the windows were broken, Officer Garcia placed K-9 Bolt in the vehicle. Initially, Officer Garcia, Officer Skaggs, Officer R. Miller, and Officer Munoz approached the vehicle's right passenger side. Officer Garcia attempted to open the vehicle's sliding door, but it was jammed. Officer Garcia, Officer Urquizo, and Detective Skaggs repositioned to the left side of the suspect vehicle. I approached them as they were having difficulty removing the suspect from the vehicle. As they took the suspect down to the ground, K-9 Bolt held the suspect's right shoulder. I saw blood on the suspect, and officers grabbed his arms. I placed my knee between his shoulders so officers could cuff him.
#
# AMR and Fire responded to the scene, and eventually, the suspect was transported by AMR to NMC for treatment of the dog bite.
#
# A vehicle search was conducted, and an item containing contraband and illegal drugs was located by the driver-side seat. For further details, refer to Officer Urquizo's supplement report. I observed the suspect's cell phone was on the ground by the driver's side. This item was booked into evidence by CSO Quintero. CSO Stephanie Moore took photographs of the scene.
#
# California Towing towed the suspect vehicle. I observed after removing my SUV. The damage to the vehicle only appeared to be to the push bumper. The left side of the push bumper was pushed inward, almost touching the surface of the front grill area.
#
# It should be mentioned when the suspect vehicle was pushed into the lemon tree; the tree fell on a parked vehicle in the driveway of That vehicle is a 2012 white BMW, Lic plate # We were unable to verify if there was body damage to the vehicle due to the tree limbs covering the vehicle. Officer Munoz contacted the neighbor, who spoke with the owner of the BMW by phone. A report number was provided to the neighbor for the owner of the vehicle.
#
# I spoke with Sgt. Jeff Carr of Marina PD. He provided me with some details regarding their case. I was informed that they would submit a booking sheet to Monterey County Jail for the charges incurred by the suspect in their jurisdiction. For further details, refer to Marina PD Case # 23-2228.
#
# | REPORTING OFFICER SIGNATURE / DATE                    | SUPERVISOR SIGNATURE / DATE                          |
# | ----------------------------------------------------- | ---------------------------------------------------- |
# | Rodolfo Roman #75561 Oct 21, 2023 11:09 (e-signature) | Danny Warner #92283 Oct 23, 2023 20:43 (e-signature) |
# | PRINT NAME                                            | PRINT NAME                                           |
# | Rodolfo Roman #75561                                  | Danny Warner #92283                                  |
#
# Salinas Police Department
# <page_footer>Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35</page_footer>
#
#
#
# Report # 23-100611 - Supplement - 4 Report Salinas Police Department
#
# This concluded my involvement in this case.
#
# # INVOLVED PERSONS
#
# # INVOLVED PERSON-1
#
# NAME (LAST, FIRST MIDDLE): P-1 Ayon, Ruben Jr
#
# DOB / ESTIMATED AGE RANGE: 1981-04-02
#
# SEX: Male
#
# RACE / ETHNICITY: Hispanic
#
# HOME ADDRESS: No Fixed Address
#
# INVOLVEMENT TYPE: Suspect
#
# # INVOLVED PERSON-2
#
# NAME (LAST, FIRST MIDDLE): P-2 Roman, Rodolfo
#
# DOB / ESTIMATED AGE RANGE:
#
# SEX: Male
#
# RACE / ETHNICITY: Hispanic
#
# PHONE NUMBER: (831) 758- (primary, Work Phone)
#
# INVOLVEMENT TYPE: Victim
#
# # INVOLVED LOCATIONS
#
# LOCATION: ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# # VEHICLE
#
# | MAKE  | MODEL   | YEAR OF MANUFACTURE |
# | ----- | ------- | ------------------- |
# | Honda | Odyssey | 2010                |
#
# ITEM CATEGORY: Multipurpose Passenger Vehicle Mpv
#
# DESCRIPTION: Stock van
#
# LICENSE PLATE / REGISTRATION #:
#
# PRIMARY COLOR: Silver
#
# REGISTRATION YEAR: 2010
#
# # OWNER
#
# STATUS (NIBRS): None
#
# STATUS DATE: Oct 20, 2023
#
# TOTAL ($) VALUE: UNKNOWN
#
# IMPOUNDED / TOWED: Yes
#
# # TOWING COMPANY
#
# ID #: California Towing
#
# QUANTITY: 1
#
# # LOCATION VEHICLE WAS TOWED TO
#
# 124 Griffin St
#
# # IN POLICE CUSTODY
#
# REASON FOR POLICE CUSTODY: Towed by PD - Safekeeping
#
# # RECOVERING OFFICER / ID # / PERSON
#
# Anthony Garcia #30349
#
# # RECOVERED LOCATION
#
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# # VEHICLE / PROPERTY &#x26; ITEMS SUMMARY
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Rodolfo Roman #75561 Oct 21, 2023 11:09 (e-signature)
#
# PRINT NAME: Rodolfo Roman #75561
#
# # SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 20:43 (e-signature)
#
# PRINT NAME: Danny Warner #92283
#
# Pg 4 of 5
#
#
#
# Report # 23-100611 - Supplement - 4 Report Salinas Police Department
#
# | DESCRIPTION / MAKE / MODEL / COLOR   | STATUS / DATE / REASON FOR CUSTODY | VIN # / SERIAL # | QTY. | TOTAL ($) |
# | ------------------------------------ | ---------------------------------- | ---------------- | ---- | --------- |
# | Stock van / Honda / Odyssey / Silver | None / Oct 20, 2023 / Safekeeping  | UNKNOWN          | 1    | VALUE     |
#
# REPORTING OFFICER SIGNATURE / DATE
#
# Rodolfo Roman #75561 Oct 21, 2023 11:09 (e-signature)
#
# SUPERVISOR SIGNATURE / DATE
#
# Danny Warner #92283 Oct 23, 2023 20:43 (e-signature)
#
# PRINT NAME
#
# Rodolfo Roman #75561
#
# PRINT NAME
#
# Danny Warner #92283
#
# Salinas Police Department
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35.
#
# Pg 5 of 5
#
#
#
# Report # 23-100611 - Supplement - 5 Report Salinas Police Department
#
# # Report # 23-100611 - Supplement - 5 Report
#
# | REPORT DATE / TIME | EVENT START DATE / TIME - EVENT END DATE / TIME | PREPARED BY       |
# | ------------------ | ----------------------------------------------- | ----------------- |
# | Oct 23, 2023 16:54 | Oct 23, 2023 16:54 - 16:54                      | Alyssa Maniscalco |
#
# # REPORT DESCRIPTION
#
# Supplement
#
# # SUPPLEMENT TYPE
#
# Add Property/Evidence
#
# # NARRATIVE
#
# On 10/23/2023 myself and Evidence Technician A. Serrano processed dry locker 1.
#
# Before removing the items, dry locker number 1 it was secured with one red zip tie with serial number 0269736. The red zip tie was collected and entered into evidence as item 9.
#
# I removed the following items from dry locker 1:
#
# - Item 5 described as "Black sweater w/ blood from suspect"
# - Item 10 described as "Dry locker #1 butcher paper and transport bag for item #5."
# - Item 9 described as "Dry locker 1 red zip tie with serial #0269736"
#
# All items were packaged, sealed and placed into evidence.
#
# Prior to closing locker 1, it was properly sanitized.
#
# Nothing further.
#
# # VEHICLE / PROPERTY &#x26; ITEMS SUMMARY
#
# | DESCRIPTION / MAKE / MODEL / COLOR                        | STATUS / DATE / REASON FOR CUSTODY | VIN # / SERIAL # | QTY. | TOTAL ($) |
# | --------------------------------------------------------- | ---------------------------------- | ---------------- | ---- | --------- |
# | Dry locker #1 red zip-tie with serial #0269736            | None / Oct 23, 2023 / Evidence     |                  |      | UNKNOWN   |
# | Dry locker #1 butcher paper and transport bag for item #5 | None / Oct 23, 2023 / Evidence     |                  |      | UNKNOWN   |
#
# # PROPERTY &#x26; ITEMS ADDENDUM
#
# 23-100611-9 OTHER ITEM - DRY LOCKER #1 RED ZIP-TIE WITH SERIAL #0269736
#
# # ITEM CATEGORY
#
# Other
#
# # DESCRIPTION
#
# Dry locker #1 red zip-tie with serial #0269736
#
# # STATUS (NIBRS)
#
# None
#
# # STATUS DATE
#
# Oct 23, 2023
#
# # TOTAL ($)
#
# VALUE
#
# UNKNOWN
#
# # IN POLICE CUSTODY/ TOWED BY PD
#
# Yes
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Alyssa Maniscalco Oct 23, 2023 17:03 (e-signature)
#
# # PRINT NAME
#
# Alyssa Maniscalco
#
# Salinas Police Department
#
# Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
# # SUPERVISOR SIGNATURE / DATE
#
# Evelia Marr #54654 Oct 23, 2023 20:02 (e-signature)
#
# # PRINT NAME
#
# Evelia Marr #54654
#
# Pg 1 of 2
#
#
#
#
# Report # 23-100611 - Supplement - 5 Report Salinas Police Department
#
# # REASON FOR POLICE CUSTODY
#
# | EVIDENCE                                                |                                                                                     |              |                    |             |
# | ------------------------------------------------------- | ----------------------------------------------------------------------------------- | ------------ | ------------------ | ----------- |
# | RECOVERING OFFICER /ID # / PERSON                       | Alyssa Maniscalco                                                                   |              |                    |             |
# | STORAGE LOCATION / PERSON / DESTINATION / INTAKE PERSON | MAIN FACILITY > EVIDENCE INTAKE                                                     |              |                    |             |
# |                                                         | 23-100611-10 OTHER ITEM - DRY LOCKER #1 BUTCHER PAPER AND TRANSPORT BAG FOR ITEM #5 |              |                    |             |
# | ITEM CATEGORY                                           | Other                                                                               |              |                    |             |
# | DESCRIPTION                                             | Dry locker #1 butcher paper and transport bag for item #5                           |              |                    |             |
# | STATUS (NIBRS)                                          | None                                                                                |              |                    |             |
# |                                                         | STATUS DATE                                                                         | Oct 23, 2023 |                    |             |
# |                                                         |                                                                                     | TOTAL ($)    | VALUE              |             |
# |                                                         |                                                                                     |              | IN POLICE CUSTODY/ | TOWED BY PD |
# |                                                         |                                                                                     | UNKNOWN      | Yes                |             |
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# | Alyssa Maniscalco | Oct 23, 2023 17:03 (e-signature) |
# | ----------------- | -------------------------------- |
#
# # SUPERVISOR SIGNATURE / DATE
#
# | Evelia Marr #54654 | Oct 23, 2023 20:02 (e-signature) |
# | ------------------ | -------------------------------- |
#
# # PRINT NAME
#
# Alyssa Maniscalco
# Evelia Marr #54654
#
# Salinas Police Department
#
#
#
#
# Report # 23-100611 - Supplement - 6 Report Salinas Police Department
#
# # Report # 23-100611 - Supplement - 6 Report
#
# | REPORT DATE / TIME | EVENT START DATE / TIME - EVENT END DATE / TIME | PREPARED BY       |
# | ------------------ | ----------------------------------------------- | ----------------- |
# | Nov 27, 2023 15:06 | Oct 23, 2023 16:54 - 16:54                      | Ivan Urquizo #231 |
#
# # REPORT DESCRIPTION
#
# Supplement
#
# # SUPPLEMENT TYPE
#
# Add Property/Evidence
#
# # NARRATIVE
#
# I rebooked items 1 and 2 from my previous supplement to contain the proper item category so they can be attached to the incident report charges.
#
# Item 1 was rebooked as item 11.
#
# Item 2 was rebooked as item 12.
#
# Item 1 and 2 can be cleared from evidence.
#
# # INVOLVED PERSONS
#
# | INVOLVED PERSON-1 NAME (LAST, FIRST MIDDLE) | DOB / ESTIMATED AGE RANGE |
# | ------------------------------------------- | ------------------------- |
# | P-1 Ayon, Ruben Jr                          | 1981-04-02                |
# | SEX                                         | RACE / ETHNICITY          |
# | Male                                        | Hispanic                  |
# | HOME ADDRESS                                | No Fixed Address          |
# | INVOLVEMENT TYPE                            | Suspect                   |
#
# # INVOLVED ORGANIZATIONS
#
# | INVOLVED ORGANIZATION-1 NAME |        |
# | ---------------------------- | ------ |
# | O-1 STATE OF CALIFORNIA      |        |
# | INVOLVEMENT TYPE             | Victim |
#
# # INVOLVED LOCATIONS
#
# LOCATION
#
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# # VEHICLE / PROPERTY &#x26; ITEMS SUMMARY
#
# | DESCRIPTION / MAKE / MODEL / COLOR | STATUS / DATE / REASON FOR CUSTODY | VIN # / SERIAL # | QTY.  | TOTAL ($) |
# | ---------------------------------- | ---------------------------------- | ---------------- | ----- | --------- |
# | 118 Blue M30 Pills                 | Seized / Oct 20, 2023 / Evidence   | UNKNOWN          | 14.92 | VALUE     |
# | 2.53 Grams of methamphetamine      | Seized / Oct 20, 2023 / Evidence   | UNKNOWN          | 2.53  | UNKNOWN   |
#
# # PROPERTY &#x26; ITEMS ADDENDUM
#
# 23-100611-11 DRUGS - 118 BLUE M30 PILLS
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Ivan Urquizo #231 Nov 27, 2023 15:16 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Ruben Sanchez #76997 Nov 27, 2023 18:05 (e-signature)
#
# PRINT NAME
#
# Ivan Urquizo #231
#
# PRINT NAME
#
# Ruben Sanchez #76997
#
# Salinas Police Department Pg1 of 2 Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35
#
#
#
# Report # 23-100611 - Supplement - 6 Report Salinas Police Department
# # DRUG CATEGORY
#
# | Fentanyl | YES | NO |
# | -------- | --- | -- |
#
# # EXPLAIN BIOHAZARD
#
# Possible fentanyl
#
# # DESCRIPTION
#
# 118 Blue M30 Pills
#
# # IN POSSESSION OF
#
# Ruben Ayon Jr
#
# # STATUS (NIBRS)
#
# # STATUS DATE
#
# # TOTAL ($)
#
# # QUANTITY, MEASUREMENT
#
# | Seized | Oct 20, 2023 | UNKNOWN | 14.92 | Gram |
# | ------ | ------------ | ------- | ----- | ---- |
#
# # IN POLICE CUSTODY/ REASON FOR POLICE CUSTODY
#
# TOWED BY PD
#
# Evidence
#
# Yes
#
# # RECOVERING OFFICER /ID # / PERSON
#
# Ivan Urquizo #231
#
# # STORAGE LOCATION / PERSON / DESTINATION / INTAKE PERSON
#
# MAIN FACILITY > INTAKE LOCKERS
#
# # RECOVERED LOCATION
#
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# # 23-100611-12 DRUGS - 2.53 GRAMS OF METHAMPHETAMINE
#
# # DRUG CATEGORY
#
# | Amphetamines | Methamphetamines |
# | ------------ | ---------------- |
#
# # DESCRIPTION
#
# 2.53 Grams of methamphetamine
#
# # IN POSSESSION OF
#
# Ruben Ayon Jr
#
# # STATUS (NIBRS)
#
# # STATUS DATE
#
# # TOTAL ($)
#
# # QUANTITY, MEASUREMENT
#
# | Seized | Oct 20, 2023 | UNKNOWN | 2.53 | Gram |
# | ------ | ------------ | ------- | ---- | ---- |
#
# # IN POLICE CUSTODY / REASON FOR POLICE CUSTODY
#
# TOWED BY PD
#
# Evidence
#
# Yes
#
# # RECOVERING OFFICER / ID # / PERSON
#
# Ivan Urquizo #231
#
# # STORAGE LOCATION / PERSON / DESTINATION / INTAKE PERSON
#
# MAIN FACILITY > INTAKE LOCKERS
#
# # RECOVERED LOCATION
#
# ALAMEDA AVE &#x26; E ROMIE LN, SALINAS, CA 93901
#
# # REPORTING OFFICER SIGNATURE / DATE
#
# Ivan Urquizo #231 Nov 27, 2023 15:16 (e-signature)
#
# # SUPERVISOR SIGNATURE / DATE
#
# Ruben Sanchez #76997 Nov 27, 2023 18:05 (e-signature)
#
# # PRINT NAME
#
# Ivan Urquizo #231
#
# # PRINT NAME
#
# Ruben Sanchez #76997
#
# Salinas Police Department
# <page_footer>Mark43 RMS Form v2.0 generated by A. Medrano #56524 on Aug 21, 2024 17:35</page_footer>

# %%
# PARSE FIRST n PDFs

num_records = 3
results = {}

for i in range(num_records):
    pdf_path = DATA_DIR / f"record{i}.pdf"

    if not pdf_path.exists():
        print(f"{pdf_path.name} not found")
        continue

    print(f"Parsing: {pdf_path.name}")

    parser_temp = LlamaParse(
        api_key=os.getenv("LLAMA_CLOUD_API_KEY"),
        result_type="markdown",
        verbose=True,
        language="en",
    )

    documents = parser_temp.load_data(str(pdf_path))
    content = "\n\n".join([doc.text for doc in documents])
    results[pdf_path.name] = content
    print(f"Parsing complete: {len(content)} characters, {len(documents)} page(s) \n")

print(f"\nParsed {len([r for r in results.values() if r])} out of {num_records} records successfully")
# Out:
# Parsing: record0.pdf
# Started parsing the file under job_id 8fa8cd3c-cc1b-4a49-b875-02ec8289bbbc
# Parsing complete: 1520 characters, 1 page(s)
#
# Parsing: record1.pdf
# Started parsing the file under job_id 6c4ddd08-3ace-4170-8bfb-b2c4596fd89b
# Parsing complete: 4072 characters, 2 page(s)
#
# Parsing: record2.pdf
# Started parsing the file under job_id 55b423f2-4db7-4cdd-8dfb-040fa19d54c4
# Parsing complete: 13037 characters, 4 page(s)
#
#
# Parsed 3 out of 3 records successfully

# %%
# SUMMARY OF PARSED DATA

import pandas as pd

summary = []
for filename, content in results.items():
    if content:
        summary.append({
            'filename': filename,
            'length': len(content),
            'lines': content.count('\n'),
            'words': len(content.split()),
        })

df_summary = pd.DataFrame(summary)
df_summary
# Out:
#       filename  length  lines  words
# 0  record0.pdf    1520     14    156
# 1  record1.pdf    4072     93    609
# 2  record2.pdf   13037    222   1904
