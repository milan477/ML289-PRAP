# %%
# !pip install pymupdf4llm
# !pip install PyMuPDF
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 16.5 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pymupdf4llm
import pymupdf
import pandas as pd

# %%
"""def get_text_percentage(file_name):

    Calculate the percentage of document that is covered by (searchable) text.

    If the returned percentage of text is very low, the document is
    most likely a scanned PDF
    REFERENCE MATERIAL: https://stackoverflow.com/questions/55704218/how-to-check-if-pdf-is-scanned-image-or-contains-text

    total_page_area = 0.0
    total_text_area = 0.0

    doc = fitz.open(file_name)
    for page_num, page in enumerate(doc):
        total_page_area = total_page_area + abs(page.rect)
        text_area = 0.0
        for b in page.getTextBlocks():
            r = fitz.Rect(b[:4])
            text_area = text_area + abs(r)
        total_text_area = total_text_area + text_area
    doc.close()
    return total_text_area / total_page_area"""
# Out:
# 'def get_text_percentage(file_name):\n\n    Calculate the percentage of document that is covered by (searchable) text.\n\n    If the returned percentage of text is very low, the document is\n    most likely a scanned PDF\n    REFERENCE MATERIAL: https://stackoverflow.com/questions/55704218/how-to-check-if-pdf-is-scanned-image-or-contains-text\n\n    total_page_area = 0.0\n    total_text_area = 0.0\n\n    doc = fitz.open(file_name)\n    for page_num, page in enumerate(doc):\n        total_page_area = total_page_area + abs(page.rect)\n        text_area = 0.0\n        for b in page.getTextBlocks():\n            r = fitz.Rect(b[:4])\n            text_area = text_area + abs(r)\n        total_text_area = total_text_area + text_area\n    doc.close()\n    return total_text_area / total_page_area'

# %%
def get_image_count(file):
  doc = pymupdf.open(file)
  for pg_idx in range(len(doc)):
    page = doc[pg_idx]
    image_list = page.get_images()
    if image_list:
      print(f"Found {len(image_list)} images on page {pg_idx}")
    else:
      print("No images found on page", pg_idx)
  return len(image_list)

    #  for image_index, img in enumerate(image_list, start=1): # enumerate the image list
    #     xref = img[0]
    #     pix = pymupdf.Pixmap(doc, xref)
    #     if pix.n - pix.alpha > 3:
    #       pix = pymupdf.Pixmap(pymupdf.csRGB, pix)

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# /Users/milanliessens/Documents/Education/Universities/Berkeley/MEng/Fall 2025/CS 289 - ML/Grad Project/src/pipeline

# %%
def create_df():
    files = {"record" : [], "text_len": [], "num_images": []}
    for i in range(10):
        file = f"../../data/records/record{i}.pdf"
        md_text = pymupdf4llm.to_markdown(file)
        # md_text = ""
        # if get_text_percentage(file) > 0.05:
        #     md_text = pymupdf4llm.to_markdown(file)
        files["record"].append(file)
        files["text_len"].append(len(md_text))
        files["num_images"].append(get_image_count(file))
    files_df = pd.DataFrame(files)
    files_df.head()
    return files_df
df = create_df()
df.head()
# Out:
# No images found on page 0
# Found 2 images on page 0
# Found 2 images on page 1
# Found 2 images on page 0
# Found 2 images on page 1
# Found 2 images on page 2
# Found 2 images on page 3
# Found 1 images on page 0
# Found 1 images on page 1
# Found 1 images on page 2
# Found 1 images on page 3
# Found 1 images on page 4
# Found 1 images on page 5
# Found 1 images on page 6
# Found 1 images on page 7
# Found 1 images on page 8
# Found 1 images on page 9
# Found 1 images on page 10
# Found 1 images on page 11
# Found 1 images on page 12
# Found 1 images on page 13
# Found 1 images on page 14
# Found 1 images on page 15
# Found 1 images on page 16
# Found 1 images on page 17
# Found 1 images on page 18
# Found 1 images on page 19
# Found 1 images on page 20
# Found 1 images on page 21
# Found 1 images on page 22
# Found 1 images on page 23
# Found 1 images on page 24
# Found 1 images on page 25
# Found 1 images on page 26
# Found 1 images on page 27
# Found 1 images on page 28
# ...
